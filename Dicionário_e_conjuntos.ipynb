# %% [markdown]
# <a href="https://colab.research.google.com/github/MuriloRamos45/P.A./blob/main/Dicion%C3%A1rio_e_conjuntos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1
aluno = {
    "nome": "Murilo",
    "idade": 15,
    "curso": "Informática"
}

print(aluno)
# Out:
# {'nome': 'Murilo', 'idade': 15, 'curso': 'Informática'}

# %%
# 2
aluno = {
    "nome": "Murilo",
    "idade": 15,
    "curso": "Informática"
}

print(aluno["nome"])
print(aluno["idade"])
print(aluno["curso"])
# Out:
# Murilo
# 15
# Informática

# %%
# 3
produto = {
    "nome": "Caderno",
    "preco": 20,
    "estoque": 50
}

produto["preco"] = 25

print(produto)
# Out:
# {'nome': 'Caderno', 'preco': 25, 'estoque': 50}

# %%
# 4
aluno = {
    "nome": "Murilo",
    "idade": 15
}

aluno["curso"] = "Informática"

print(aluno)
# Out:
# {'nome': 'Murilo', 'idade': 15, 'curso': 'Informática'}

# %%
# 5
filme = {
    "titulo": "Clube da Luta",
    "ano": 1999,
    "genero": "Ação",
    "nota": 10
}

print(filme["titulo"])
print(filme["ano"])
print(filme["genero"])
print(filme["nota"])
# Out:
# Clube da Luta
# 1999
# Ação
# 10

# %%
#1

numeros = {1, 2, 3, 4, 5}

print(numeros)
# Out:
# {1, 2, 3, 4, 5}

# %%
# 2
numeros = {1, 2, 2, 3, 3, 3, 4, 5}

print(numeros)
# Out:
# {1, 2, 3, 4, 5}

# %%
# 3
frutas = {"maçã", "banana", "laranja"}

frutas.add("morango")

print(frutas)

# %%
# 4
cores = {"vermelho", "azul", "verde", "amarelo"}

cores.remove("verde")

print(cores)
# Out:
# {'amarelo', 'vermelho', 'azul'}

# %%
#5
nomes = ["Yris", "Luna", "Luna", "Maitê", "Yris", "Ravi", "Gael", "Theo", "Theo"]

nomes = set(nomes)

print(nomes)
# Out:
# {'Yris', 'Ravi', 'Theo', 'Luna', 'Maitê', 'Gael'}
