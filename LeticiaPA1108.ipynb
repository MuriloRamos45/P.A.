# %% [markdown]
# <a href="https://colab.research.google.com/github/MuriloRamos45/P.A./blob/main/LeticiaPA1108.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1

nome = "Vanessa Tipi Tipi Landão"
idade = 696769
altura = 167.67
nota = (-1)
cidade = "Ouro Fino Muquifo"

print(nome)
print(type(nome))

print(idade)
print(type(idade))

print(altura)
print(type(altura))

print(nota)
print(type(nota))

print(cidade)
print(type(cidade))
# Out:
# Vanessa Tipi Tipi Landão
# <class 'str'>
# 696769
# <class 'int'>
# 167.67
# <class 'float'>
# -1
# <class 'int'>
# Ouro Fino Muquifo
# <class 'str'>

# %%
#2

a = 7.5
b = 8.0
c = 6.5

media = (a + b + c) / 3

print(media)
# Out:
# 7.333333333333333

# %%
#3

texto1 = "20"
texto2 = "3.5"
numero = 8

a = int(texto1) + 10
b = float(texto2) * 2
c = str(numero) + " anos"

print(a)
print(b)
print(c)
# Out:
# 30
# 7.0
# 8anos

# %%
#4

print(f"O dobro de 15 é igual a {15 * 2}")
print(f"A metade de 90 é igual a {90 / 2}")
print(f"O resto da divisão de 17 por 5 é igual a {17 % 5}")
print(f"2 elevados à potência 4 é igual a {2 ** 4}")
print(f"A média de 10, 8 e 6 é igual a {(10 + 8 + 6) / 3}")
# Out:
# O dobro de 15 é igual a 30
# A metade de 90 é igual a 45.0
# O resto da divisão de 17 por 5 é igual a 2
# 2 elevados à potência 4 é igual a 16
# A média de 10, 8 e 6 é igual a 8.0

# %%
#5

idade = 16
nota = 8.5
preco = 45.0

print(f"Idade >= 18 {idade >= 18}")
print(f"Nota > 7 {nota > 7}")
print(f"Preço <= 50 {preco <= 50}")
print(f"Idade == 16 {idade == 16}")
print(f"Nota != 10 {nota != 10}")
# Out:
# Idade >= 18 False
# Nota > 7 True
# Preço <= 50 True
# Idade == 16 True
# Nota != 10 True

# %%
#6

a = 80

print(f"O desconto foi de {80 * 0.1} reais")

vf = float(80 - (80 * 0.1))
print(f"O valor final a pagar é de {vf} reais")
print(f"Valor final a pagar é maior que 75 {vf > 75}")
# Out:
# O desconto foi de 8.0 reais
# O valor final a pagar é de 72.0 reais
# Valor final a pagar é maior que 75 False

# %%
#7

n = str(input("Qual o nome do aluno? "))
a = float(input("Qual foi a primeira nota? "))
b = float(input("Qual foi a segunda nota? "))

media = (a + b) / 2

print(f"O aluno {n} tirou a média {media}")
# Out:
# Qual o nome do aluno? a
# Qual foi a primeira nota? 10
# Qual foi a segunda nota? 0
# O aluno a tirou a média 5.0
