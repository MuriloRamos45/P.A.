# %% [markdown]
# <a href="https://colab.research.google.com/github/MuriloRamos45/P.A./blob/main/Listas%20e%20Tuplas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1

frutas = ["Maçã", "Banana", "Laranja", "Morango"]
print(frutas)
# Out:
# ['Maçã', 'Banana', 'Laranja', 'Morango']

# %%
#2

nomes = ["Rebeca", "Guilherme", "Melissa", "Kyara"]
print(nomes[0])
print(nomes[1])
print(nomes[3])
# Out:
# Rebeca
# Guilherme
# Kyara

# %%
#3

cores = ["Vermelho", "Azul", "Verde"]
cores[1] = "Amarelo"
print(cores)
# Out:
# ['Vermelho', 'Amarelo', 'Verde']

# %%
#4

alunos = ["Nicolas", "Wendel", "Pyetra"]
alunos.append("Petros")
print(alunos)
# Out:
# ['Nicolas', 'Wendel', 'Pyetra', 'Petros']

# %%
#5

animais = ["Cachorro", "Gato", "Coelho", "Passarinho"]
animais.remove("Coelho")
print(animais)
# Out:
# ['Cachorro', 'Gato', 'Passarinho']

# %%
#Tuplas

#1

meses = ("Janeiro", "Fevereiro", "Março", "Abril")
print(meses)
# Out:
# ('Janeiro', 'Fevereiro', 'Março', 'Abril')

# %%
#2

numeros = (10,20,30,40,50)
print(numeros[0])
print(numeros[2])
print(numeros[4])
# Out:
# 10
# 30
# 50

# %%
#3

aluno = ("Murilo", 15, "Informática")
print(aluno[0])
print(aluno[1])
print(aluno[2])
# Out:
# Murilo
# 15
# Informática

# %%
#4

cores = ("Vermelho", "Azul", "Verde")
cores[1] = "Amarelo"
#TypeError: 'tuple' object does not support item assignment
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2048/1762195415.py in <cell line: 0>()
#       1 cores = ("Vermelho", "Azul", "Verde")
# ----> 2 cores[1] = "Amarelo"
#
# TypeError: 'tuple' object does not support item assignment

# %%
#5

numeros = (2,4,2,6,2,10)
print(numeros.count(2))
# Out:
# 3
