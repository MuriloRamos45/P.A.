# %% [markdown]
# <a href="https://colab.research.google.com/github/MuriloRamos45/P.A./blob/main/Programa%C3%A7%C3%A3o%20e%20Algoritimos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula de programação e algoritimos
#
#
#
# *   Cálculo da área
#
# # Entrada
#
# *   Ler lado 1
# *  Ler lado 2
#
# # Processamento
#
# área = lado1 * lado2
#
# #Saída
#
# imprimir área

# %%
# Cálculo da área

#Entrada

lado1 = 5

lado2 = 4

nome = "Murilo Ramos" #str

idade = 15 #int
altura = 1.80 # float
numero_complexo = 6 + 9j #complex
esta_chovendo = False #bool

# %%
#Processamento

area = lado1*lado2

# %%
#Saída

print(f"Total da área: {area}")
print (f"Nome: {nome}")
print (f"Idade: {idade}")
print (f"Altura: {altura}")
# Out:
# Total da área: 20
# Nome: Murilo Ramos
# Idade: 15
# Altura: 1.8
